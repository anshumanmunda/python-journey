# %% [markdown]
# # Python Decorator

# %% [markdown]
# #### 1. Create a 'shout' decorator that uppercases the returned string.

# %%
import functools
import time
# write your code here 
def upper_case(s):
  pass

st = "anshu"

# %% [markdown]
# #### 2. Create a 'double_call' decorator that runs a function twice.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 3. Create a decorator that prints 'Starting...' and 'Finished!'.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 4. Write a 'timer' decorator using the time module.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 5. Apply a decorator using @ syntax that prints a border of stars.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 6. Create a 'log_args' decorator to print *args and **kwargs.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 7. Create a 'require_auth' decorator that checks a boolean variable.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 8. Create a decorator that validates if the first argument is an integer.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 9. Use functools.wraps to preserve function metadata in a decorator.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 10. Create a simple 'memoize' decorator for caching results.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 11. Create a decorator that adds a 2-second delay (time.sleep).

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 12. Create a parameterized decorator that runs a function 'n' times.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 13. Create a decorator that enforces a string return type.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 14. Create an exception-handling decorator that prevents crashes.

# %%
import functools
import time
# write your code here

# %% [markdown]
# #### 15. Apply two decorators (bold and italic) to one function and check order.

# %%
import functools
import time
# write your code here
